# %% [markdown]
# ### TODO:
# Run the code to mesure FID and report it in this notebook, do it for both 0.0 and 7.5 guidance scales, as requested.
# ###

# %%
######## TODO ########
# Edit and run a command to to measure FID between two directories (7.5 scale)
# %%bash
python image_diffusion_todo/fid/measure_fid.py /home/student/DDIM/data/afhq/eval /home/student/DDIM/generated_images_scale_7.5
######################

# %%
######## TODO ########
# Edit and run a command to to measure FID between two directories (0.0 scale)
# %%bash
python image_diffusion_todo/fid/measure_fid.py /home/student/DDIM/data/afhq/eval /home/student/DDIM/generated_images_scale_0.0
######################
